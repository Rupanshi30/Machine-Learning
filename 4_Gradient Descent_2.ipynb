# %% [markdown]
# #### Gradient Descent: It is one of optimizing technique to get the best fit line in LR by optimizing the value of m and b. In a way, it finds the optimal value of m and b where error or residual is minimum.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats as st
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

import seaborn as sns
import pylab
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error as mse, mean_absolute_error as mae,r2_score

# %%
df=pd.read_csv("C:\\Users\\rupan\\Downloads\\placement.csv")
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
x=df[["cgpa"]]
y=df["package"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
import numpy as np
n = len(x_train)# Number of elements in X
epochs =1000 ## no of iterations
m=0.5 ## can take any random value
b=2   ## can take any random value
l=0.0001
for i in range(epochs): 
    #y_pred = m*x_train["cgpa"] + b  # The current predicted value of Y
    slope_m = (-2)*np.sum(x_train["cgpa"]*(y_train -(m*x_train["cgpa"]+b))) # Derivative wrt m
    slope_b = (-2)*np.sum(y_train-m*x_train["cgpa"]-b)  # Derivative wrt b
    m = m - l * slope_m # Update m
    b = b - l * slope_b  # Update b
    #y_pred=m*x_train["cgpa"]+b
    #e=np.sum((y_train-y_pred)**2)
    #print(e)
    print (m, b)
#print(y_pred)
# Out:
# -0.05542351000000001 1.920277
# 0.2977244395155482 1.96747223581814
# 0.07396918118154897 1.934082454122275
# 0.21652170732480241 1.9518630803552768
# 0.12648457796481377 1.9371552202099822
# 0.18413129173248324 1.9430785853728494
# 0.14800492484797428 1.935904496583931
# 0.17141999017041676 1.9370491779508359
# 0.15702852439781792 1.9329142685773903
# 0.16664219717947068 1.932134126970901
# 0.16101332078012467 1.9292263139685881
# 0.1650624486545312 1.9276719352124325
# 0.16296612713121406 1.925260640157604
# 0.1647715526593361 1.923395902282102
# 0.16409919822900218 1.9211865759669122
# 0.16499978277831293 1.9191984976637222
# 0.16490127842603983 1.91707238437746
# 0.16543680984906067 1.915036363219893
# 0.1655694150485454 1.912945581756314
# 0.16595751947143567 1.910892013138932
# 0.16618305220288535 1.908817256703559
# 0.16651147010769526 1.9067583925380882
# 0.16677422001361789 1.904691874659175
# 0.16707832600754427 1.9026326519699521
# 0.1673558327533165 1.9005712308172604
# ...

# %% [markdown]
# - value of m and b 0.17141999017041676, 1.9370491779508359
